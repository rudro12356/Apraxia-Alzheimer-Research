# %%
import pandas as pd
import numpy as np

# %%
GESTURES_DESCRIPTIONS_FILE = "P2_3_skeleton.csv"
metadata_df = pd.read_csv(GESTURES_DESCRIPTIONS_FILE)
metadata_df
# Out:
#       patient_id action             joint_0             joint_7  \
# 0     Patient_46   P2_3   [0.5388, 0.45143]  [0.55981, 0.43221]
# 1     Patient_46   P2_3  [0.53866, 0.45118]  [0.55926, 0.43264]
# 2     Patient_46   P2_3  [0.53677, 0.45883]  [0.55968, 0.43356]
# 3     Patient_46   P2_3  [0.53963, 0.45502]  [0.55899, 0.43219]
# 4     Patient_46   P2_3  [0.53822, 0.45363]  [0.56018, 0.43157]
# ...          ...    ...                 ...                 ...
# 3481  Patient_05   P2_3   [0.53547, 0.2458]   [0.56108, 0.2412]
# 3482  Patient_05   P2_3  [0.53588, 0.25236]  [0.56117, 0.24323]
# 3483  Patient_05   P2_3  [0.53645, 0.24621]   [0.56164, 0.2406]
# 3484  Patient_05   P2_3  [0.53552, 0.25565]   [0.56048, 0.2434]
# 3485  Patient_05   P2_3   [0.53581, 0.2538]  [0.56054, 0.24405]
#
#                  joint_8            joint_11            joint_12  \
# 0     [0.50888, 0.44071]  [0.59369, 0.54679]  [0.47473, 0.55047]
# ...

# %%
s = '2015-12-07T11-17-29.622000-bgrimage.jpg'
s.split('.',2)
# Out:
# ['2015-12-07T11-17-29', '622000-bgrimage', 'jpg']
